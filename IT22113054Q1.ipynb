# %% [markdown]
# <a href="https://colab.research.google.com/github/kahingala/DLlab5/blob/main/IT22113054Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1 - Implement a Simple RNN to Predict the Next Value in a Small Sequence of Numbers**
#
# ***Read the following descriptions and instructions***
#
# In time-series analysis, predicting future values based on past observations is a fundamental task. Recurrent Neural Networks (RNNs) are particularly well-suited for this type of problem due to their ability to maintain a memory of previous inputs through their recurrent connections.
#
# In this task, you will work with a synthetic dataset that represents a simple sine wave. The sine wave is a periodic function and serves as a good example to understand how RNNs can capture patterns and make predictions.
#
# A **sine wave** is a fundamental waveform that is widely used in various fields, including signal processing, physics, and time-series analysis. It is characterized by its smooth, periodic oscillations, making it an ideal example for understanding time-series prediction tasks.![11.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# The generate_sine_wave function generates a synthetic sine wave dataset, which is often used in time-series prediction tasks, particularly for training models like RNNs and LSTMs.
#
#
# **seq_length=100**: This parameter is intended to specify the length of the sequence that you want to generate
#
# **num_samples=1000**:This parameter determines the number of data points (samples) to generate for the sine wave.

# %%
# 1. Generate a Synthetic Sine Wave Dataset
def generate_sine_wave(seq_length=100, num_samples=1000):
    x = np.linspace(0, 50, num_samples)
    y = np.sin(x)
    return y

# %% [markdown]
# The create_dataset function prepares the sine wave data for use in an RNN by converting the continuous data into sequences that the RNN can learn from. The time_step parameter in the create_dataset function represents the number of previous time points (or observations) that are used as input to predict the next time point in a sequence.

# %%
# 2. Prepare the Dataset for RNN
def create_dataset(data, time_step=10):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step)])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %% [markdown]
# To prepare the data for modeling, it is important to normalize it so that all values fall within a specific range, typically between 0 and 1. This step improves the performance and convergence of neural network models.
#
# The MinMaxScaler from sklearn.preprocessing is used for this purpose. It scales the data such that the minimum value of the data becomes 0 and the maximum value becomes 1.
#
# The sine wave data is reshaped into a 2D array (-1, 1) to fit the scaler, as it expects a 2D input. After scaling, the data is reshaped back into its original 1D form.

# %%
# Generate and Normalize the Data
data = generate_sine_wave()
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data.reshape(-1, 1)).reshape(-1)

# %%
# Create the Dataset
time_step = 10  # Time steps for RNN input
X, y = create_dataset(data, time_step)

# %%
# Reshape for RNN input [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# This division of data helps in evaluating the model’s performance by training it on a substantial portion of the data and testing its predictions on unseen data.

# %%
# Split the Data into Training and Testing Sets (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ***Modify the units parameter in the SimpleRNN layer to see how the number of hidden units affects the model's ability to learn the sequence.***
#
#
# **optimizer='adam':** Uses the Adam optimizer, which is a popular choice for training deep learning models due to its adaptive learning rate.
#
#
# **loss='mean_squared_error':** Sets the loss function to mean squared error (MSE), which is commonly used for regression tasks to measure the average squared difference between predicted and actual values.

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ***Adjust the epochs and batch_size during the training phase to optimize the model's learning process and performance.***
#
# an
#
# **epochs=20:** Specifies the number of times the entire training dataset will pass through the model.
#
#
# **batch_size=32:** Determines the number of samples per gradient update.
#
# **verbose=1:** Provides detailed output during training, including the progress of each epoch and loss values.

# %%
# 4. Train the Model
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0174
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5801e-04
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9378e-04
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6372e-04
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2103e-04
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5125e-04
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9274e-04
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7520e-04
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2697e-04
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8671e-05
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3051e-04
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9296e-05
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7805e-05
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1492e-05
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6886e-05
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8031e-05
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9654e-05
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7263e-05
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0104e-05
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9968e-05
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5740e-05
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8412e-05
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7943e-05
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9115e-05
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8444e-05
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6499e-05
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9523e-05
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4436e-05
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2406e-05

# %%
# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c2f1d296160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %% [markdown]
# These steps reverse the normalization applied earlier to the predictions and actual values. Normalization scales the data to a range, typically [0, 1], which helps with model training but makes the results difficult to interpret directly.
# By applying the inverse transformation, you convert the scaled predictions (y_pred) and test values (y_test) back to their original scale, allowing you to evaluate and visualize the model's performance in the context of the original data values.

# %%
# Inverse transform to get the original scale (if normalization was applied)
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).reshape(-1)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).reshape(-1)

# %% [markdown]
# This plot visually compares the actual sine wave values (y_test) with the values predicted by the RNN model (y_pred).
#
# By plotting both sets of values on the same graph, you can easily see how well the model's predictions align with the actual data.
#
# This visualization helps in assessing the performance of the RNN model and understanding how accurately it captures the underlying pattern in the time series data.
#
# ***Analyze the resulting plot. If the predicted values deviate significantly from the actual values, experiment with different model configurations and training parameters to improve accuracy.***
#
# # **Describe your observations. You can add a text cell and type your observations.**

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=16, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 4. Train the Model
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0131
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4058e-04
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3076e-04
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7846e-04
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6474e-04
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7021e-04
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1848e-04
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0517e-04
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2580e-05
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0417e-05
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6505e-05
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9619e-05
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0202e-05
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7694e-05
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6584e-05
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0437e-05
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0352e-05
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2519e-05
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2604e-05
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9026e-05
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0765e-05
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1860e-05
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3023e-05
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6826e-05
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0418e-05
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0172e-05
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4812e-05
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4772e-05
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4385e-05

# %%
# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c2efacd5f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=32, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 4. Train the Model
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1500
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0739e-04
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3361e-04
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0912e-04
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6546e-04
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5284e-04
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0099e-04
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0330e-04
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8072e-04
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8537e-04
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1820e-04
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7871e-04
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0534e-04
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4630e-04
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2090e-04
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1111e-04
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8363e-04
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1129e-04
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9848e-04
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4001e-04
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2519e-04
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3508e-04
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1972e-04
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9363e-04
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8519e-04
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6907e-04

# %%
# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=8, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 4. Train the Model
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3604
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1587
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0589
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4400e-04
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7673e-04
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4094e-04
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3824e-04
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2154e-04
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7707e-04
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1270e-04
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5169e-04
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4487e-04

# %%
# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')# 4. Train the Model
model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4650
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8704e-04
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0522e-04
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3312e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')# 4. Train the Model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1777
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0144
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5526e-04
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1052e-04
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8222e-04
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3213e-04
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1161e-04
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3366e-04
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3914e-04
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9958e-04
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7311e-04
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0756e-04
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7383e-04
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2917e-04
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8866e-04
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6956e-04
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6024e-04
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2782e-04
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0148e-04
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1348e-04
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8325e-04
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8939e-04
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5913e-04
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5920e-04
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4726e-04
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2715e-04
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3483e-04
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9978e-04
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9415e-04
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9934e-04
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5770e-04
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7621e-04
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3363e-04
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3799e-04
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3022e-04
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2253e-04
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1820e-04
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1435e-04
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9976e-04
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9300e-04
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8568e-04
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7157e-04
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7472e-04
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7041e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')# 4. Train the Model
model.fit(X_train, y_train, epochs=30, batch_size=8, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()
# Out:
# Epoch 1/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0333
# Epoch 2/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5700e-04
# Epoch 3/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.8056e-04
# Epoch 4/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8818e-04
# Epoch 5/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3540e-04
# Epoch 6/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8991e-04
# Epoch 7/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3446e-04
# Epoch 8/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.9168e-04
# Epoch 9/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3401e-04
# Epoch 10/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5716e-05
# Epoch 11/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.3287e-05
# Epoch 12/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.9438e-05
# Epoch 13/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5806e-05
# Epoch 14/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.1450e-05
# Epoch 15/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.7536e-05
# Epoch 16/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.7583e-05
# Epoch 17/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1392e-05
# Epoch 18/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1828e-06
# Epoch 19/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6507e-06
# Epoch 20/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1372e-06
# Epoch 21/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4288e-05
# Epoch 22/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4340e-06
# Epoch 23/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.2575e-06
# Epoch 24/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5881e-05
# Epoch 25/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0307e-06
# Epoch 26/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.7436e-06
# Epoch 27/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4746e-06
# Epoch 28/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3976e-06
# Epoch 29/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.4884e-06
# Epoch 30/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7754e-06
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
